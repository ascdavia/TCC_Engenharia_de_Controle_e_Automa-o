# %% [markdown]
# Database 1

# %%
import pandas as pd

# %%
f1_cyl = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_1/f1_cyl.csv?raw=true', compression = None, header = None)
f1_hook = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_1/f1_hook.csv?raw=true', compression = None, header = None)
f1_lat = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_1/f1_lat.csv?raw=true', compression = None, header = None)
f1_palm = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_1/f1_palm.csv?raw=true', compression = None, header = None)
f1_spher = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_1/f1_spher.csv?raw=true', compression = None, header = None)
f1_tip = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_1/f1_tip.csv?raw=true', compression = None, header = None)

f2_cyl = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_2/f2_cyl.csv?raw=true', compression = None, header = None)
f2_hook = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_2/f2_hook.csv?raw=true', compression = None, header = None)
f2_lat = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_2/f2_lat.csv?raw=true', compression = None, header = None)
f2_palm = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_2/f2_palm.csv?raw=true', compression = None, header = None)
f2_spher = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_2/f2_spher.csv?raw=true', compression = None, header = None)
f2_tip = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_2/f2_tip.csv?raw=true', compression = None, header = None)

f3_cyl = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_3/f3_cyl.csv?raw=true', compression = None, header = None)
f3_hook = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_3/f3_hook.csv?raw=true', compression = None, header = None)
f3_lat = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_3/f3_lat.csv?raw=true', compression = None, header = None)
f3_palm = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_3/f3_palm.csv?raw=true', compression = None, header = None)
f3_spher = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_3/f3_spher.csv?raw=true', compression = None, header = None)
f3_tip = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/female_3/f3_tip.csv?raw=true', compression = None, header = None)

m1_cyl = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/male_1/m1_cyl.csv?raw=true', compression = None, header = None)
m1_hook = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/male_1/m1_hook.csv?raw=true', compression = None, header = None)
m1_lat = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/male_1/m1_lat.csv?raw=true', compression = None, header = None)
m1_palm = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/male_1/m1_palm.csv?raw=true', compression = None, header = None)
m1_spher = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/male_1/m1_spher.csv?raw=true', compression = None, header = None)
m1_tip = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/male_1/m1_tip.csv?raw=true', compression = None, header = None)

m2_cyl = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/male_2/m2_cyl.csv?raw=true', compression = None, header = None)
m2_hook = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/male_2/m2_hook.csv?raw=true', compression = None, header = None)
m2_lat = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/male_2/m2_lat.csv?raw=true', compression = None, header = None)
m2_palm = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/male_2/m2_palm.csv?raw=true', compression = None, header = None)
m2_spher = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/male_2/m2_spher.csv?raw=true', compression = None, header = None)
m2_tip = pd.read_csv('https://github.com/ascdavia/TCC_Engenharia_de_Controle_e_Automacao/blob/main/Database/sEMG_Basic_Hand_movements_upatras_csv_files/Database_1/male_2/m2_tip.csv?raw=true', compression = None, header = None)

# %%
cyl = pd.concat([f1_cyl,f2_cyl,f3_cyl,m1_cyl,m2_cyl], ignore_index=True)
hook = pd.concat([f1_hook,f2_hook,f3_hook,m1_hook,m2_hook], ignore_index=True)
lat = pd.concat([f1_lat,f2_lat,f3_lat,m1_lat,m2_lat], ignore_index=True)
palm = pd.concat([f1_palm,f2_palm,f3_palm,m1_palm,m2_palm], ignore_index=True)
spher = pd.concat([f1_spher,f2_spher,f3_spher,m1_spher,m2_spher], ignore_index=True)
tip = pd.concat([f1_tip,f2_tip,f3_tip,m1_tip,m2_tip], ignore_index=True)

# %%
x = pd.concat([cyl,hook,lat,palm,spher,tip], ignore_index=True)
x
# Out:
#          0         1         2         3         4         5         6     \
# 0   -0.129990 -0.002497  0.329070  0.227060 -0.027969 -0.002454 -0.027956
# 1    0.023017  0.176050  0.150570  0.125020  0.125100 -0.283000 -0.231970
# 2   -0.104490  0.023041  0.125070  0.048555 -0.257510 -0.308490 -0.180980
# 3    0.252520 -0.155450 -0.640060 -0.461490 -0.333990 -0.078984  0.150540
# 4   -0.563530 -0.487030  0.150550  0.329050  0.278070  0.074062 -0.078984
# ..        ...       ...       ...       ...       ...       ...       ...
# 895 -0.078984  0.048531  0.074044 -0.027969 -0.334040  0.048555 -0.002454
# 896 -0.155500 -0.129990 -0.155480 -0.104500 -0.181010 -0.002461  0.099564
# 897 -0.053495 -0.027987 -0.053470 -0.027969  0.099583 -0.053470  0.125070
# 898 -0.002491  0.023010 -0.130010 -0.002467  0.201560  0.278080  0.023084
# 899 -0.232020 -0.027974 -0.078984 -0.232030 -0.181000 -0.002448  0.150590
#
#          7         8         9     ...     2990     2991      2992      2993  \
# ...

# %%
x.to_csv('df1_mov_all.csv')

# %%
cyl.to_csv('df1_mov_cyl.csv')
hook.to_csv('df1_mov_hook.csv')
lat.to_csv('df1_mov_lat.csv')
palm.to_csv('df1_mov_palm.csv')
spher.to_csv('df1_mov_spher.csv')
tip.to_csv('df1_mov_tip.csv')
